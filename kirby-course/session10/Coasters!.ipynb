# %%
import pandas
import sqlite3 as sql

# %%
conn = sql.connect("roller_coasters.db")
curs = conn.cursor()

# %%
df = pandas.read_sql_query("SELECT * FROM coasters ORDER BY name", conn)

# %%
df['Name'][:10]
# Out:
# 0             Afterburner
# 1              Alpengeist
# 2          American Eagle
# 3        Apollo's Chariot
# 4    Batman Knight Flight
# 5                   Beast
# 6             Blue Streak
# 7                    Boss
# 8             Cannon Ball
# 9          Canyon Blaster
# Name: Name, dtype: object

# %%
conn.close()

# %%
df
# Out:
#                              Name                                    Park  \
# 0                     Afterburner                                Fun Spot
# 1                      Alpengeist              Busch Gardens Williamsburg
# 2                  American Eagle                 Six Flags Great America
# 3                Apollo's Chariot              Busch Gardens Williamsburg
# 4            Batman Knight Flight           Six Flags Worlds of Adventure
# 5                           Beast                Paramount's Kings Island
# 6                     Blue Streak                             Cedar Point
# 7                            Boss                     Six Flags St. Louis
# 8                     Cannon Ball                      Lake Winnepesaukah
# 9                  Canyon Blaster                           Adventuredome
# 10                          Chang              Six Flags Kentucky Kingdom
# 11                        Cheetah                         Wild Adventures
# ...
