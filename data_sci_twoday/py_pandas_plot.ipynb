# %%
#py_pandas_plot.ipynb
# %matplotlib inline
import pandas as pd
ser=pd.Series([2,8,8,2,3,6,1])

#these run one per code cell in practice - consolidated here
plot=ser.plot(kind='hist')

# %%
plot=ser.plot(kind='bar')

# %%
plot=ser.plot(kind='line')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-9df239d38210> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.bar([2,8,8,2,3,6,1])
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
import numpy as np
df = pd.DataFrame(np.random.rand(10, 3), columns=['c1', 'c2', 'c3'])
df.plot.bar()
df.plot.barh(stacked=True)

# %%
df.plot.barh(stacked=True)
